# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import os
from sklearn.linear_model import LinearRegression

from poisson_custom import process_sku

from outliners_fix import zscore, plot_zscore, cap_outliers, plot_cap_outliers
from data_split import get_season, date_split
from errors_custom import errors
from state_space_custom import state_space, fit_ucm_and_evaluate, state_space_out
from xgb_poisson_custom import fit_xgb_poisson2, fit_xgb_poisson2_out
from corr_custom import means_and_cor
from poisson_custom import sku_extract, plot_SKU, generate_calendar, pred_out, plot_forecast_with_intervals
from xgb_cv import xgb_cv

# %% [markdown]
# ## SKU bunch

# %%
# upload initial data from file
filename = f"data/mock_test.csv"
df = pd.DataFrame()
df = pd.read_csv(filename,sep=',')
SKU_list = df['ITEM_CODE'].unique()

filename_out = f"data/mock_out.csv"
try:
    os.remove(filename_out)
except FileNotFoundError:
    pass

# %%
# pd.set_option('future.no_silent_downcasting', True)

# for SKU in SKU_list:
#     _ = process_sku(df, SKU)

# %%
pd.set_option('future.no_silent_downcasting', True)

for SKU in SKU_list:

    print(f"Processing SKU: {SKU}")

    # 1) Extract SKU data
    df_cl = sku_extract(df, SKU)

    # 2) Compute z-score for VALUE
    n=max(round(len(df_cl.index)/10),30)
    df_cl['VALUE2'] = zscore(df_cl['VALUE'], window=n)

    avg, m = zscore(df_cl['VALUE'], window=n, return_all=True)
    plot_zscore(df_cl, avg, m)


    # 3) Data prep

    date_split(df_cl)
    plot_SKU(df_cl, y_col='VALUE2', title='Sold per day, no outliers')

    #  7 day rolling mean
    plt.figure(figsize=(12, 5))  # Set figure size
    df_cl['VALUE2'].rolling(window=7).mean().plot(
        lw=2,
        color='blue',
        label='7-day Rolling Mean'
    )

    plt.xlabel('Time Index')          # X-axis label
    plt.ylabel('VALUE2')              # Y-axis label
    plt.title('7-day Rolling Mean of VALUE2')  # Plot title
    plt.legend()                       # Show legend
    plt.grid(True, alpha=0.3)          # Optional: add light grid
    plt.show()                         # Display the plot

    # mean for weekdays, month and season
    # means_and_cor(df_cl)

    # # check if there non zero trend
    # X = np.arange(len(df_cl)).reshape(-1, 1)
    # y = df_cl['VALUE2'].values
    # model = LinearRegression().fit(X, y)
    
    # if abs(model.coef_[0]) < 0.01:
    #     trend = False
    #     print("No sufficient trend:", model.coef_[0], "cross-validation with window 7 will be used")

    # else:
    #     trend = True
    #     print("There is some trend:", model.coef_[0], "80:20 split will be used")

    

    # 4) XGBoost no cross-validation and with cross-validation
    print("XGBoost evaluation 80/20:")
    max_len = df_cl["VALUE2"].groupby((df_cl["VALUE2"] != df_cl["VALUE2"].shift()).cumsum()).size().max()
    max_run = max(max_len, 7)
    results = fit_xgb_poisson2(df_cl, test_size=0.2, max_lag=max_run+1, plot=True)  # other good option space_state function

    print("Test MAE (mean):", results["mae_mean"])
    print("Test MAE (integer):", results["mae_integer"])
    print("Test MAPE (mean):", results["mape_mean"])
    print("Test MAPE (integer):", results["mape_integer"])
    print("Sample (test) variance:", results["var_test_sample"])
    var1 = results["var_test_sample"]
    
    window = 30
    if len(df_cl.index) > window*2:
    
        print("XGBoost evaluation with cross validation, window =", window, ":")

        results = xgb_cv(df_cl, max_lag=7, window=window, plot=True)

        
        print(f"Window: {window}")
        print("Test MAE (mean):", results["mae_mean"])
        print("Test MAE (integer):", results["mae_integer"])
        print("Test MAPE (mean):", results["mape_mean"])
        print("Test MAPE (integer):", results["mape_integer"])
        print("Sample (test) variance:", results["var_test_sample"])
        var1 = results["var_test_sample"]

    # 6) Generate forecast calendar
    df_pred = generate_calendar('2025-09-01','2025-09-30')

    # 7) Fit XGBoost Poisson and get forecasts
    
    df_pred = fit_xgb_poisson2_out(df_cl, df_pred, max_lag=max_run+1, n=30)

    # 8) Generate final prediction dataframe with intervals
    df_out = pred_out(df_pred, SKU, var1)

    # 9) Plot forecasts with intervals
    plot_forecast_with_intervals(df_out)

    # 10) Save or append to CSV
    filename_out = f"data/mock_out.csv"
    if os.path.exists(filename_out):
        df_out.to_csv(filename_out, mode='a', index=False, header=False)
    else:
        df_out.to_csv(filename_out, mode='w', index=False, header=True)
# Out:
# Processing SKU: 111900-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 0.9513043780957372
# Test MAE (integer): 0.9421487603305785
# Test MAPE (mean): 49.88393431736363
# Test MAPE (integer): 49.30555555555556
# Sample (test) variance: 1.4455922865013773
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 1.1835372770504493
# Test MAE (integer): 1.1821428571428572
# Test MAPE (mean): 61.32357405796959
# Test MAPE (integer): 61.14206128133704
# Sample (test) variance: 2.1034372604140046
# Processing SKU: 111934-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 6.516791881978019
# Test MAE (integer): 6.4958677685950414
# Test MAPE (mean): 71.42603206271319
# Test MAPE (integer): 70.93352876577977
# Sample (test) variance: 44.61101928374656
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 4.350632671546191
# Test MAE (integer): 4.358928571428572
# Test MAPE (mean): 72.49412936644146
# Test MAPE (integer): 73.49271073852277
# Sample (test) variance: 28.763835292614363
# Processing SKU: 121234-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 7.648389305211296
# Test MAE (integer): 7.669421487603306
# Test MAPE (mean): 68.90854775582545
# Test MAPE (integer): 69.18884894774988
# Sample (test) variance: 58.00358126721763
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 5.023496190684715
# Test MAE (integer): 5.0125
# Test MAPE (mean): 66.54205121847012
# Test MAPE (integer): 66.15814031186915
# Sample (test) variance: 34.03953168924098
# Processing SKU: 121914-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 6.812263800092965
# Test MAE (integer): 6.809917355371901
# Test MAPE (mean): 59.21783615351994
# Test MAPE (integer): 59.23067217664404
# Sample (test) variance: 52.860743801652895
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 4.9821356244252195
# Test MAE (integer): 4.9875
# Test MAPE (mean): 66.51173282104114
# Test MAPE (integer): 66.82632187539163
# Sample (test) variance: 33.59337784308714
# Processing SKU: 121987-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 0.48065051436424255
# Test MAE (integer): 0.4358974358974359
# Test MAPE (mean): 96.47544720492355
# Test MAPE (integer): 100.0
# Sample (test) variance: 0.9320660182729152
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 0.4424596595530082
# Test MAE (integer): 0.3892857142857143
# Test MAPE (mean): 91.29090656368368
# Test MAPE (integer): 95.7957957957958
# Sample (test) variance: 0.7474444160490672
# Processing SKU: 177714-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 1.765131838373409
# Test MAE (integer): 1.7933884297520661
# Test MAPE (mean): 67.94203385678877
# Test MAPE (integer): 67.77777777777779
# Sample (test) variance: 3.478925619834711
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 1.395145844362144
# Test MAE (integer): 1.3839285714285714
# Test MAPE (mean): 65.29457461017059
# Test MAPE (integer): 66.55188246097336
# Sample (test) variance: 2.4475817786864296
# Processing SKU: 261514-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 1.6519564754706768
# Test MAE (integer): 1.628099173553719
# Test MAPE (mean): 27.66896935816794
# Test MAPE (integer): 27.292464193290638
# Sample (test) variance: 4.142561983471074
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 1.760492570911135
# Test MAE (integer): 1.7571428571428571
# Test MAPE (mean): 27.275649741058544
# Test MAPE (integer): 27.241377669949095
# Sample (test) variance: 4.640825453616151
# Processing SKU: 561934-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 3.3069093562354728
# Test MAE (integer): 3.28099173553719
# Test MAPE (mean): 34.704183434346355
# Test MAPE (integer): 34.335366194870325
# Sample (test) variance: 13.52396694214876
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 3.6314095033066613
# Test MAE (integer): 3.6125
# Test MAPE (mean): 49.292455960079955
# Test MAPE (integer): 48.94225219225219
# Sample (test) variance: 16.322741502683364
# Processing SKU: 661914-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 4.146237050206208
# Test MAE (integer): 4.140495867768595
# Test MAPE (mean): 69.9087022383083
# Test MAPE (integer): 69.54074621429993
# Sample (test) variance: 22.499035812672172
# XGBoost evaluation with cross validation, window = 30 :
# c:\Users\yulia\Documents\Stats&DA_job\TimeSeries_SKU_forecast\xgb_cv.py:75: RuntimeWarning: invalid value encountered in cast
#   "pred_integer": np.round(y_preds).astype(int),
# Window: 30
# Test MAE (mean): 3.5820959401982173
# Test MAE (integer): 3.5625
# Test MAPE (mean): 63.0123510542413
# Test MAPE (integer): 62.662721702900285
# Sample (test) variance: 18.13659276769742
# Processing SKU: 991234-A
# XGBoost evaluation 80/20:
# Test MAE (mean): 5.132418870925903
# Test MAE (integer): 5.0
# Test MAPE (mean): 37.08037766543302
# Test MAPE (integer): 36.36363636363637
# Sample (test) variance: 44.785714285714285
